# %% [markdown]
# <a href="https://colab.research.google.com/github/THANUSH0000/python-machine-earning/blob/main/pandas%203%20-%20115.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#creating series from array
arr=np.array(['p','a','n','d','a','s'])
a=pd.Series(arr)
print("Series from array")
print(a)
# Out:
# Series from array
# 0    p
# 1    a
# 2    n
# 3    d
# 4    a
# 5    s
# dtype: object

# %%
#series from dictionary
arr={'x':0,'y':1,'z':2}
b=pd.Series(arr)
print("\n\n series from dictionary:|n")
print(b)
# Out:
#  series from dictionary:|n
# x    0
# y    1
# z    2
# dtype: int64

# %%
#series using scalar
x=pd.Series(4,index=[0,1,2,3])
print("\n series using scalar|n")
print(x)
# Out:
#  series using scalar|n
# 0    4
# 1    4
# 2    4
# 3    4
# dtype: int64

# %%
#series through index
x=pd.Series([1,2,3],index=['a','b','c'])
print("\n series through index:")
print(x)
# Out:
#  series through index:
# a    1
# b    2
# c    3
# dtype: int64

# %%
a=pd.Series(data=[1,2,3,4])
print("\n a series:\n",a)
print("\n Index:\n",a.index)
print("\n values:\n",a.values)
print("\n shape:",a.shape)
print("\n dimension:",a.ndim)
print("\n size:",a.size)
# Out:
#  a series:
#  0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
#
#  Index:
#  RangeIndex(start=0, stop=4, step=1)
#
#  values:
#  [1 2 3 4]
#
#  shape: (4,)
#
#  dimension: 1
#
#  size: 4
